# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import scipy.stats as ss
import numpy as np
import matplotlib.pyplot as plt
plt.figure(num=None, figsize=(10, 5), dpi=80, facecolor='w', edgecolor='r')
x = np.arange(-10, 11)
xU, xL = x + 0.5, x - 0.5 
prob = ss.norm.cdf(xU, scale = 3) - ss.norm.cdf(xL, scale = 3)
prob = prob / prob.sum() #normalize the probabilities so their sum is 1
nums = np.random.choice(x, size = 10000, p = prob)
plt.hist(nums, bins = len(x), color='pink', edgecolor='k', alpha=0.65)
# Out:
# (array([  14.,   29.,   76.,  162.,  325.,  502.,  796., 1103., 1338.,
#         1301.,    0., 1302., 1041.,  792.,  548.,  320.,  187.,  101.,
#           45.,   11.,    7.]),
#  array([-9.        , -8.0952381 , -7.19047619, -6.28571429, -5.38095238,
#         -4.47619048, -3.57142857, -2.66666667, -1.76190476, -0.85714286,
#          0.04761905,  0.95238095,  1.85714286,  2.76190476,  3.66666667,
#          4.57142857,  5.47619048,  6.38095238,  7.28571429,  8.19047619,
#          9.0952381 , 10.        ]),
#  <a list of 21 Patch objects>)

# %%
import matplotlib.pyplot as plt
import numpy as np


Fs = 100
f = 2
sample = 100
x = np.arange(sample)
y = np.sin(2 * np.pi * f * x / Fs)
z = 5*x + 2 + np.random.uniform(-100,100, size=(100,))
w = 5*x + 4
plt.scatter(x, y)
plt.plot(x,y, color='red')
plt.xlabel('Independent Variable(X)')
plt.ylabel('Dependent Variable(Y)')
plt.show()

# %%
plt.scatter(x, z)
plt.plot(x, w, color = 'red')
plt.xlabel('Independent Variable(X)')
plt.ylabel('Dependent Variable(Y)')
plt.show()

# %%
import pandas as pd
data = pd.DataFrame()
data['sample']=x
data['sine']=y
data['linear']=z

# %%
data.corr()
# Out:
#           sample      sine    linear
# sample  1.000000 -0.389355  0.938770
# sine   -0.389355  1.000000 -0.361088
# linear  0.938770 -0.361088  1.000000

# %%
from sklearn.feature_selection import mutual_info_regression

# %%
data.iloc[:,1:2]
# Out:
#             sine
# 0   0.000000e+00
# 1   1.253332e-01
# 2   2.486899e-01
# 3   3.681246e-01
# 4   4.817537e-01
# 5   5.877853e-01
# 6   6.845471e-01
# 7   7.705132e-01
# 8   8.443279e-01
# 9   9.048271e-01
# 10  9.510565e-01
# 11  9.822873e-01
# 12  9.980267e-01
# 13  9.980267e-01
# 14  9.822873e-01
# 15  9.510565e-01
# 16  9.048271e-01
# 17  8.443279e-01
# 18  7.705132e-01
# 19  6.845471e-01
# 20  5.877853e-01
# 21  4.817537e-01
# 22  3.681246e-01
# 23  2.486899e-01
# 24  1.253332e-01
# 25  1.224647e-16
# 26 -1.253332e-01
# 27 -2.486899e-01
# 28 -3.681246e-01
# 29 -4.817537e-01
# ..           ...
# 70  5.877853e-01
# 71  4.817537e-01
# 72  3.681246e-01
# 73  2.486899e-01
# 74  1.253332e-01
# 75  3.673940e-16
# 76 -1.253332e-01
# 77 -2.486899e-01
# 78 -3.681246e-01
# 79 -4.817537e-01
# 80 -5.877853e-01
# 81 -6.845471e-01
# 82 -7.705132e-01
# 83 -8.443279e-01
# 84 -9.048271e-01
# 85 -9.510565e-01
# 86 -9.822873e-01
# 87 -9.980267e-01
# 88 -9.980267e-01
# 89 -9.822873e-01
# ...

# %%
mi=mutual_info_regression(data, data['sample'])
# Out:
# C:\Users\Public\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)

# %%
t = pd.DataFrame()
t['relationsip']=['sine','linear']
t['mi_score']=mi[1:]

# %%
t
# Out:
#   relationsip  mi_score
# 0        sine  0.791653
# 1      linear  1.065037

# %%
data = pd.read_excel(r'Data_Train.xlsx')
test = pd.read_excel(r'Data_Test.xlsx')

# %%
data.shape, test.shape
# Out:
# ((6019, 13), (1234, 12))

# %%
data.head(5)
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
list(data.columns)
varssss= ['Name',  'Location',  'Year', 'Kilometers_Driven',  'Fuel_Type',  'Transmission',  'Owner_Type',  'Mileage',  'Engine', 'Power',  'Seats',  'New_Price',  'Price']

# %%
data.columns, test.columns
# Out:
# (Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#         'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#         'New_Price', 'Price'],
#        dtype='object'),
#  Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#         'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#         'New_Price'],
#        dtype='object'))

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven        Seats        Price
# count  6019.000000       6.019000e+03  5977.000000  6019.000000
# mean   2013.358199       5.873838e+04     5.278735     9.479468
# std       3.269742       9.126884e+04     0.808840    11.187917
# min    1998.000000       1.710000e+02     0.000000     0.440000
# 25%    2011.000000       3.400000e+04     5.000000     3.500000
# 50%    2014.000000       5.300000e+04     5.000000     5.640000
# 75%    2016.000000       7.300000e+04     5.000000     9.950000
# max    2019.000000       6.500000e+06    10.000000   160.000000

# %%
data.Name.value_counts() #1876 names
# Out:
# Mahindra XUV500 W8 2WD                               49
# Maruti Swift VDI                                     45
# Maruti Swift Dzire VDI                               34
# Honda City 1.5 S MT                                  34
# Maruti Swift VDI BSIV                                31
# Hyundai i10 Sportz                                   30
# Maruti Ritz VDi                                      30
# Toyota Fortuner 3.0 Diesel                           29
# Hyundai Grand i10 Sportz                             27
# Honda Amaze S i-Dtech                                27
# Maruti Ertiga VDI                                    25
# Honda Brio S MT                                      25
# Honda City 1.5 V MT                                  24
# Maruti Wagon R VXI                                   23
# Hyundai Verna 1.6 SX                                 23
# Maruti Wagon R LXI                                   22
# Maruti Alto LXi                                      21
# ...

# %%
def company(item):
    return item.split()[0]

# %%
data['Company']=data['Name'].apply(company)
test['Company']=test['Name'].apply(company)

# %%
data[data['Company']=='Chevrolet']['Price'].mean()
# Out:
# 3.0444628099173556

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[(data['Company']=='Maruti')]['Price'])
x = np.array(data[(data['Company']=='Maruti')]['Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 4.517266721717589 4.15

# %%
check = np.log(data[data['Company']=='Maruti']['Price'])

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(check)
x = np.array(check)
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 1.3573291444976492 1.423108334242607

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data['Price'])
x = np.array(data['Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 9.47946835022429 5.64

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(np.log(data['Price']))
x = np.array(np.log(data['Price']))
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 1.8250951269849505 1.7298840655099674

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[(data['Company']=='Hyundai')]['Price'])
x = np.array(data[(data['Company']=='Hyundai')]['Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 5.343432700993677 4.6

# %%
check = np.log(data[data['Company']=='Maruti']['Price'])

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(check)
x = np.array(check)
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 1.3573291444976492 1.423108334242607

# %%
data['Log_Price']=np.log(data['Price'])

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[(data['Company']=='Hyundai')]['Log_Price'])
x = np.array(data[(data['Company']=='Hyundai')]['Log_Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 1.5004057558823223 1.5260563034950492

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[(data['Company']=='Maruti')]['Log_Price'])
x = np.array(data[(data['Company']=='Maruti')]['Log_Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 1.3573291444976492 1.423108334242607

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[(data['Company']=='Honda')]['Price'])
x = np.array(data[(data['Company']=='Honda')]['Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 5.411743421052631 4.95

# %%
data.Company.value_counts()
# Out:
# Maruti           1211
# Hyundai          1107
# Honda             608
# Toyota            411
# Mercedes-Benz     318
# Volkswagen        315
# Ford              300
# Mahindra          272
# BMW               267
# Audi              236
# Tata              186
# Skoda             173
# Renault           145
# Chevrolet         121
# Nissan             91
# Land               60
# Jaguar             40
# Fiat               28
# Mitsubishi         27
# Mini               26
# Volvo              21
# Porsche            18
# Jeep               15
# Datsun             13
# Force               3
# ISUZU               2
# Lamborghini         1
# Smart               1
# Ambassador          1
# Bentley             1
# Isuzu               1
# Name: Company, dtype: int64

# %%
data.Company.value_counts(normalize=True).cumsum()
# Out:
# Maruti           0.201196
# Hyundai          0.385114
# Honda            0.486127
# Toyota           0.554411
# Mercedes-Benz    0.607244
# Volkswagen       0.659578
# Ford             0.709420
# Mahindra         0.754610
# BMW              0.798970
# Audi             0.838179
# Tata             0.869081
# Skoda            0.897824
# Renault          0.921914
# Chevrolet        0.942017
# Nissan           0.957136
# Land             0.967104
# Jaguar           0.973750
# Fiat             0.978402
# Mitsubishi       0.982888
# Mini             0.987207
# Volvo            0.990696
# Porsche          0.993687
# Jeep             0.996179
# Datsun           0.998339
# Force            0.998837
# ISUZU            0.999169
# Lamborghini      0.999335
# Smart            0.999502
# Ambassador       0.999668
# Bentley          0.999834
# Isuzu            1.000000
# Name: Company, dtype: float64

# %%
rare = data.Company.value_counts()[data.Company.value_counts(normalize=True).cumsum()>0.95].index

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[(data['Company'].isin(rare))]['Log_Price'])
x = np.array(data[(data['Company'].isin(rare))]['Log_Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 2.4917828652671035 2.772588722239781

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[~(data['Company'].isin(rare))]['Log_Price'])
x = np.array(data[~(data['Company'].isin(rare))]['Log_Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 1.7840591445051495 1.7047480922384253

# %%
def p(item):
    if item in rare:
        return 'Others'
    else:
        return item
data['P_Company']=data['Company'].apply(p)
test['P_Company']=test['Company'].apply(p)

# %%
data['P_Company'].value_counts()
# Out:
# Maruti           1211
# Hyundai          1107
# Honda             608
# Toyota            411
# Others            349
# Mercedes-Benz     318
# Volkswagen        315
# Ford              300
# Mahindra          272
# BMW               267
# Audi              236
# Tata              186
# Skoda             173
# Renault           145
# Chevrolet         121
# Name: P_Company, dtype: int64

# %%
data.to_csv(r'Processed.csv')

# %%
data.Location.value_counts() #11
# Out:
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Ahmedabad     224
# Name: Location, dtype: int64

# %%
High = 'Kochi', 'Coimbatore', 'Bangalore'
Mid = 'Mumbai', 'Hyderabad', 'Delhi', 'Ahmedabad'
Low = 'Pune', 'Kolkata', 'Chennai', 'Jaipur'

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[(data['Location']=='Ahmedabad')]['Price'])
x = np.array(data[(data['Location']=='Ahmedabad')]['Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 8.45732142857143 5.9

# %%
def p1(item):
    if item in High:
        return 'High'
    elif item in Mid:
        return 'Mid'
    else:
        return 'Low'

data['P_Location']=data['Location'].apply(p1)

# %%
data['P_Location'].value_counts()
# Out:
# Mid     2310
# Low     2064
# High    1645
# Name: P_Location, dtype: int64

# %%
data.to_csv('Processed.csv')

# %%
data.Year.value_counts()
# Out:
# 2014    797
# 2015    744
# 2016    741
# 2013    649
# 2017    587
# 2012    580
# 2011    466
# 2010    342
# 2018    298
# 2009    198
# 2008    174
# 2007    125
# 2019    102
# 2006     78
# 2005     57
# 2004     31
# 2003     17
# 2002     15
# 2001      8
# 1998      4
# 2000      4
# 1999      2
# Name: Year, dtype: int64

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[(data['Year']==2012)]['Price'])
x = np.array(data[(data['Year']==2012)]['Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 7.324724137931034 4.5

# %%
def p2(item):
    if item<2002:
        return 0
    else:
        return item

data['P_Year']=data['Year'].apply(p2)
test['P_Year']=test['Year'].apply(p2)

# %%
data.P_Year.value_counts()
# Out:
# 2014    797
# 2015    744
# 2016    741
# 2013    649
# 2017    587
# 2012    580
# 2011    466
# 2010    342
# 2018    298
# 2009    198
# 2008    174
# 2007    125
# 2019    102
# 2006     78
# 2005     57
# 2004     31
# 0        18
# 2003     17
# 2002     15
# Name: P_Year, dtype: int64

# %%
data.to_csv('Processed.csv')

# %%
data.Fuel_Type.value_counts()
# Out:
# Diesel      3205
# Petrol      2746
# CNG           56
# LPG           10
# Electric       2
# Name: Fuel_Type, dtype: int64

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[(data['Fuel_Type']=='LPG')]['Price'])
x = np.array(data[(data['Fuel_Type']=='LPG')]['Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 2.487 2.6

# %%
data.Transmission.value_counts()
# Out:
# Manual       4299
# Automatic    1720
# Name: Transmission, dtype: int64

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[(data['Transmission']=='Manual')]['Log_Price'])
x = np.array(data[(data['Transmission']=='Manual')]['Log_Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 1.484107986899966 1.5040773967762742

# %%
data.Owner_Type.value_counts()
# Out:
# First             4929
# Second             968
# Third              113
# Fourth & Above       9
# Name: Owner_Type, dtype: int64

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[(data['Owner_Type']=='Fourth & Above')]['Price'])
x = np.array(data[(data['Owner_Type']=='Fourth & Above')]['Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 3.28 3.0

# %%
data.Engine.value_counts() #146
# Out:
# 1197 CC    606
# 1248 CC    512
# 1498 CC    304
# 998 CC     259
# 2179 CC    240
# 1497 CC    229
# 1198 CC    227
# 1968 CC    216
# 1995 CC    183
# 1461 CC    152
# 2143 CC    149
# 1582 CC    145
# 1199 CC    143
# 1598 CC    141
# 1396 CC    139
# 796 CC     129
# 2494 CC    121
# 1086 CC    108
# 1591 CC     94
# 2993 CC     90
# 1399 CC     88
# 2982 CC     86
# 1798 CC     85
# 2987 CC     67
# 2967 CC     61
# 814 CC      59
# 1120 CC     54
# 1196 CC     50
# 1493 CC     47
# 1373 CC     47
#           ...
# 3436 CC      2
# 2771 CC      2
# 2360 CC      2
# 1422 CC      1
# 2995 CC      1
# 2092 CC      1
# 3200 CC      1
# 2706 CC      1
# 5998 CC      1
# 2720 CC      1
# 2694 CC      1
# 2925 CC      1
# 2495 CC      1
# 2149 CC      1
# 4951 CC      1
# 2349 CC      1
# 2112 CC      1
# 3197 CC      1
# 2999 CC      1
# 2487 CC      1
# 1797 CC      1
# 1978 CC      1
# 2147 CC      1
# 970 CC       1
# 1468 CC      1
# 72 CC        1
# 5204 CC      1
# ...

# %%
data[data['Engine'].isnull()].shape, test[test['Engine'].isnull()].shape
# Out:
# ((36, 18), (10, 15))

# %%
test[test['Engine'].isnull()]
# Out:
#                                       Name   Location  Year  \
# 23            Skoda Laura 1.8 TSI Ambition  Bangalore  2009
# 522  Toyota Etios Liva Diesel TRD Sportivo  Bangalore  2012
# 525          Hyundai i20 new Sportz AT 1.4  Bangalore  2012
# 614                    Mahindra TUV 300 P4    Kolkata  2016
# 624                BMW 5 Series 520d Sedan  Bangalore  2009
# 632                   Maruti Swift 1.3 VXi    Kolkata  2015
# 658                 Fiat Punto 1.4 Emotion     Jaipur  2010
# 666                   Maruti Swift 1.3 VXi       Pune  2010
# 861                BMW 5 Series 520d Sedan    Chennai  2009
# 883                    Toyota Etios Liva V      Kochi  2012
#
#      Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage Engine  \
# 23               72000    Petrol       Manual     Second   17.5 kmpl    NaN
# 522              56600    Diesel       Manual      First  23.59 kmpl    NaN
# ...

# %%
data['Engine'].fillna(0, inplace=True)

# %%
data.Engine.value_counts()
# Out:
# 1197 CC    606
# 1248 CC    512
# 1498 CC    304
# 998 CC     259
# 2179 CC    240
# 1497 CC    229
# 1198 CC    227
# 1968 CC    216
# 1995 CC    183
# 1461 CC    152
# 2143 CC    149
# 1582 CC    145
# 1199 CC    143
# 1598 CC    141
# 1396 CC    139
# 796 CC     129
# 2494 CC    121
# 1086 CC    108
# 1591 CC     94
# 2993 CC     90
# 1399 CC     88
# 2982 CC     86
# 1798 CC     85
# 2987 CC     67
# 2967 CC     61
# 814 CC      59
# 1120 CC     54
# 1196 CC     50
# 1373 CC     47
# 1493 CC     47
#           ...
# 2997 CC      2
# 2771 CC      2
# 2360 CC      2
# 2149 CC      1
# 4951 CC      1
# 3200 CC      1
# 1422 CC      1
# 2706 CC      1
# 2995 CC      1
# 2694 CC      1
# 2720 CC      1
# 2925 CC      1
# 2495 CC      1
# 970 CC       1
# 2092 CC      1
# 2349 CC      1
# 2112 CC      1
# 1489 CC      1
# 2773 CC      1
# 2999 CC      1
# 2487 CC      1
# 1797 CC      1
# 1468 CC      1
# 2147 CC      1
# 72 CC        1
# 1978 CC      1
# 5204 CC      1
# ...

# %%
data[data['Mileage']=='17.5 kmpl']['Engine'].value_counts()
# Out:
# 1298 CC    20
# 1197 CC     6
# 1896 CC     5
# 1199 CC     5
# 1198 CC     4
# 1798 CC     1
# 1498 CC     1
# 1373 CC     1
# Name: Engine, dtype: int64

# %%
data[data['Mileage']=='17.5 kmpl']['Power'].value_counts()
# Out:
# 85.8 bhp    26
# 106 bhp      5
# 88.7 bhp     5
# 70 bhp       2
# 75 bhp       2
# null bhp     1
# 99.6 bhp     1
# 91.1 bhp     1
# Name: Power, dtype: int64

# %%
data[data['Mileage']=='17.0 kmpl']['Seats'].value_counts()
# Out:
# 5.0    167
# 7.0      3
# Name: Seats, dtype: int64

# %%
data[data['Power']=='85.8 bhp']['Seats'].value_counts()
# Out:
# 5.0    59
# Name: Seats, dtype: int64

# %%
data['Engine'] = np.where(data['Engine']==0, data['Mileage'], data['Engine'])

# %%
data.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price', 'Company', 'Log_Price', 'P_Company', 'P_Location',
#        'P_Year'],
#       dtype='object')

# %%
c=[]
for index, row in data.iterrows():
    if row['Engine']==0:
        c.append(data[data['Mileage']==row['Mileage']]['P_Mileage'].mean())
    else:
        c.append(row['Engine'])
    #print(row['c1'], row['c2'])

# %%
c
# Out:
# ['998 CC',
#  '1582 CC',
#  '1199 CC',
#  '1248 CC',
#  '1968 CC',
#  '814 CC',
#  '1461 CC',
#  '2755 CC',
#  '1598 CC',
#  '1248 CC',
#  '1462 CC',
#  '1497 CC',
#  '1248 CC',
#  '2179 CC',
#  '2179 CC',
#  '2477 CC',
#  '1498 CC',
#  '1248 CC',
#  '1461 CC',
#  '2143 CC',
#  '1995 CC',
#  '1248 CC',
#  '1984 CC',
#  '1197 CC',
#  '1598 CC',
#  '1497 CC',
#  '1461 CC',
#  '998 CC',
#  '1199 CC',
#  '2494 CC',
#  '1461 CC',
#  '1798 CC',
#  '2696 CC',
#  '2698 CC',
#  '1598 CC',
#  '1061 CC',
#  '1248 CC',
#  '1198 CC',
#  '2987 CC',
#  '1199 CC',
#  '796 CC',
#  '624 CC',
#  '1198 CC',
#  '1197 CC',
#  '1999 CC',
#  '1798 CC',
#  '1991 CC',
#  '2694 CC',
#  '1120 CC',
#  '2498 CC',
#  '1968 CC',
#  '1248 CC',
#  '1248 CC',
#  '1248 CC',
#  '1197 CC',
#  '1598 CC',
#  '799 CC',
#  '1197 CC',
#  '1995 CC',
#  '998 CC',
#  '2393 CC',
#  '1399 CC',
#  '1796 CC',
#  '2148 CC',
#  '1396 CC',
#  '1968 CC',
#  '1497 CC',
#  '1950 CC',
#  '1248 CC',
#  '1396 CC',
#  '4806 CC',
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price', 'Company', 'Log_Price', 'P_Company', 'P_Location',
#        'P_Year'],
#       dtype='object')

# %%
check = data.groupby('Mileage').mean()

# %%
check.index.tolist()
# Out:
# ['0.0 kmpl',
#  '10.0 kmpl',
#  '10.1 kmpl',
#  '10.13 kmpl',
#  '10.2 kmpl',
#  '10.37 kmpl',
#  '10.4 kmpl',
#  '10.5 kmpl',
#  '10.6 kmpl',
#  '10.8 kmpl',
#  '10.9 kmpl',
#  '10.91 kmpl',
#  '10.93 kmpl',
#  '10.98 kmpl',
#  '11.0 kmpl',
#  '11.05 kmpl',
#  '11.07 kmpl',
#  '11.1 kmpl',
#  '11.18 kmpl',
#  '11.2 kmpl',
#  '11.25 kmpl',
#  '11.3 kmpl',
#  '11.33 kmpl',
#  '11.36 kmpl',
#  '11.4 kmpl',
#  '11.49 kmpl',
#  '11.5 kmpl',
#  '11.56 kmpl',
#  '11.57 kmpl',
#  '11.62 kmpl',
#  '11.68 kmpl',
#  '11.7 kmpl',
#  '11.72 kmpl',
#  '11.74 kmpl',
#  '11.78 kmpl',
#  '11.79 kmpl',
#  '11.8 kmpl',
#  '11.9 kmpl',
#  '12.0 kmpl',
#  '12.05 kmpl',
#  '12.07 kmpl',
#  '12.1 kmpl',
#  '12.19 kmpl',
#  '12.3 kmpl',
#  '12.35 kmpl',
#  '12.37 kmpl',
#  '12.39 kmpl',
#  '12.4 kmpl',
#  '12.5 kmpl',
#  '12.51 kmpl',
#  '12.55 kmpl',
#  '12.6 kmpl',
#  '12.62 kmpl',
#  '12.63 kmpl',
#  '12.65 kmpl',
#  '12.7 kmpl',
#  '12.8 kmpl',
#  '12.81 kmpl',
#  '12.83 kmpl',
#  '12.85 kmpl',
# ...

# %%
check.loc['17.5 kmpl']
# Out:
# Year                  2011.674419
# Kilometers_Driven    56638.581395
# Seats                    5.046512
# Price                    4.204419
# Log_Price                1.330846
# P_Year                2011.674419
# Name: 17.5 kmpl, dtype: float64

# %%
test.iloc[:,8:9]
# Out:
#        Engine
# 0      998 CC
# 1      796 CC
# 2     2393 CC
# 3     1364 CC
# 4     1197 CC
# 5     2179 CC
# 6     2982 CC
# 7      814 CC
# 8     1497 CC
# 9     2179 CC
# 10    1968 CC
# 11    1197 CC
# 12    1794 CC
# 13    1248 CC
# 14    1598 CC
# 15    1995 CC
# 16    1995 CC
# 17    1399 CC
# 18    1197 CC
# 19    1298 CC
# 20    1248 CC
# 21    1198 CC
# 22     796 CC
# 23        NaN
# 24    1799 CC
# 25    1299 CC
# 26     796 CC
# 27    1498 CC
# 28    1498 CC
# 29    1197 CC
# ...       ...
# 1204  1991 CC
# 1205  1198 CC
# 1206  1798 CC
# 1207  1086 CC
# 1208  1461 CC
# 1209  1047 CC
# 1210  1598 CC
# 1211  1197 CC
# 1212  1497 CC
# 1213  1368 CC
# 1214  1968 CC
# 1215  1591 CC
# 1216  1248 CC
# 1217  1197 CC
# 1218  1498 CC
# 1219  1968 CC
# 1220  1198 CC
# 1221  1498 CC
# 1222  2993 CC
# 1223  1197 CC
# 1224  1461 CC
# 1225  1399 CC
# 1226  1198 CC
# 1227  1197 CC
# 1228   814 CC
# 1229  1598 CC
# 1230  1197 CC
# 1231  1461 CC
# 1232  1197 CC
# 1233  2148 CC
#
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
imputer = imputer.fit(test.iloc[:,8:9]) 
test['Engine'] = imputer.transform(test.iloc[:,8:9])

# %%
test[test['Engine'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, New_Price, Company, P_Company, P_Year]
# Index: []

# %%
data=data[~(data['Engine'].isnull())]
#test=test[~(test['Engine'].isnull())]

# %%
data.shape, test.shape
# Out:
# ((6019, 18), (1234, 15))

# %%
int(data['Engine'][0].split()[0])
# Out:
# 998

# %%
def p3(item):
    """Function to extract first part of engine description and typecast to integer (Enginee CC)"""
    if(item):
        num = str(item).split()[0]
        return int(float(num))
    else:
        return item

data['P_Engine']=data['Engine'].apply(p3)
test['P_Engine']=test['Engine'].apply(p3)

# %%
data.P_Engine.value_counts()
# Out:
# 1197    606
# 1248    512
# 1498    304
# 998     259
# 2179    240
# 1497    229
# 1198    227
# 1968    216
# 1995    183
# 1461    152
# 2143    149
# 1582    145
# 1199    143
# 1598    141
# 1396    139
# 796     129
# 2494    121
# 1086    108
# 1591     94
# 2993     90
# 1399     88
# 2982     86
# 1798     85
# 2987     67
# 2967     61
# 814      59
# 1120     54
# 1196     50
# 1493     47
# 1364     47
#        ...
# 3436      2
# 2495      1
# 1422      1
# 2147      1
# 2487      1
# 2349      1
# 2149      1
# 72        1
# 20        1
# 2995      1
# 2999      1
# 2773      1
# 1948      1
# 2925      1
# 2720      1
# 2706      1
# 2092      1
# 2112      1
# 2694      1
# 1468      1
# 970       1
# 4951      1
# 1797      1
# 3200      1
# 15        1
# 3197      1
# 1978      1
# 1489      1
# 5998      1
# 5204      1
# Name: P_Engine, Length: 154, dtype: int64

# %%
data['P_Engine'].value_counts()
# Out:
# 1197    606
# 1248    512
# 1498    304
# 998     259
# 2179    240
# 1497    229
# 1198    227
# 1968    216
# 1995    183
# 1461    152
# 2143    149
# 1582    145
# 1199    143
# 1598    141
# 1396    139
# 796     129
# 2494    121
# 1086    108
# 1591     94
# 2993     90
# 1399     88
# 2982     86
# 1798     85
# 2987     67
# 2967     61
# 814      59
# 1120     54
# 1196     50
# 1493     47
# 1364     47
#        ...
# 3436      2
# 2495      1
# 1422      1
# 2147      1
# 2487      1
# 2349      1
# 2149      1
# 72        1
# 20        1
# 2995      1
# 2999      1
# 2773      1
# 1948      1
# 2925      1
# 2720      1
# 2706      1
# 2092      1
# 2112      1
# 2694      1
# 1468      1
# 970       1
# 4951      1
# 1797      1
# 3200      1
# 15        1
# 3197      1
# 1978      1
# 1489      1
# 5998      1
# 5204      1
# Name: P_Engine, Length: 154, dtype: int64

# %%
# data['P_Engine'] = np.log(data['P_Engine'])
test['P_Engine'] = np.log(test['P_Engine'])

# %%
data.Power.value_counts() #372
# Out:
# 74 bhp        235
# 98.6 bhp      131
# 73.9 bhp      125
# 140 bhp       123
# 78.9 bhp      111
# 67.1 bhp      107
# null bhp      107
# 67.04 bhp     107
# 82 bhp        101
# 88.5 bhp      100
# 117.3 bhp      93
# 118 bhp        90
# 121.3 bhp      88
# 190 bhp        79
# 126.2 bhp      78
# 170 bhp        77
# 88.7 bhp       75
# 70 bhp         75
# 86.8 bhp       74
# 80 bhp         74
# 174.33 bhp     71
# 81.86 bhp      71
# 103.6 bhp      69
# 81.83 bhp      68
# 68 bhp         62
# 68.05 bhp      61
# 85.8 bhp       59
# 184 bhp        58
# 102 bhp        57
# 120 bhp        57
#              ...
# 74.96 bhp       1
# 254 bhp         1
# 112.4 bhp       1
# 83.11 bhp       1
# 246.74 bhp      1
# 270.88 bhp      1
# 178.4 bhp       1
# 402 bhp         1
# 161.6 bhp       1
# 156 bhp         1
# 340 bhp         1
# 237.4 bhp       1
# 135.1 bhp       1
# 227 bhp         1
# 127 bhp         1
# 226.6 bhp       1
# 503 bhp         1
# 175.67 bhp      1
# 367 bhp         1
# ...

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[(data['Power']=='80 bhp')]['Price'])
x = np.array(data[(data['Power']=='80 bhp')]['Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 3.555540540540541 3.3099999999999996

# %%
data[data.Power=='null bhp']['Price'].mean()
# Out:
# 3.653084112149533

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
imputer = imputer.fit(test.iloc[:,9:10]) 
test['Power'] = imputer.transform(test.iloc[:,9:10])

# %%
def p4(item):
    num = str(item).split()[0]
    if num == 'null':
        return int(80)
    return float(num)

data['P_Power']=data['Power'].apply(p4)
test['P_Power']=test['Power'].apply(p4)

# %%
np.log(data.P_Power).hist()

# %%
data['P_Power']=np.log(data['P_Power'])
test['P_Power']=np.log(test['P_Power'])

# %%
data.Seats.value_counts()
# Out:
# 5.0     5014
# 7.0      674
# 8.0      134
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# 0.0        1
# Name: Seats, dtype: int64

# %%
data = data[data['Seats']!=0]
#test = test[test['Seats']!=0]

# %%
data.shape, test.shape
# Out:
# ((6018, 20), (1234, 17))

# %%
test.Seats.isnull().sum()
# Out:
# 11

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
imputer = imputer.fit(test.iloc[:,10:11]) 
test['Seats'] = imputer.transform(test.iloc[:,10:11])

# %%
data[data.Seats.isnull()]
# Out:
#                                               Name    Location  Year  \
# 194                             Honda City 1.5 GXI   Ahmedabad  2007
# 208                           Maruti Swift 1.3 VXi     Kolkata  2010
# 229                               Ford Figo Diesel   Bangalore  2015
# 733                           Maruti Swift 1.3 VXi     Chennai  2006
# 749                   Land Rover Range Rover 3.0 D      Mumbai  2008
# 1294                             Honda City 1.3 DX       Delhi  2009
# 1327                          Maruti Swift 1.3 ZXI   Hyderabad  2015
# 1385                            Honda City 1.5 GXI        Pune  2004
# 1460  Land Rover Range Rover Sport 2005 2012 Sport  Coimbatore  2008
# 1917                            Honda City 1.5 EXI      Jaipur  2005
# 2074                          Maruti Swift 1.3 LXI        Pune  2011
# 2096                     Hyundai Santro LP zipPlus  Coimbatore  2004
# 2264                           Toyota Etios Liva V        Pune  2012
# ...

# %%
data = data[~(data['Seats'].isnull())]
#test = test[~(test['Seats'].isnull())]

# %%
data.shape, test.shape
# Out:
# ((5976, 20), (1234, 17))

# %%
data.columns, test.columns
# Out:
# (Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#         'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#         'New_Price', 'Price', 'Company', 'Log_Price', 'P_Company', 'P_Location',
#         'P_Year', 'P_Engine', 'P_Power'],
#        dtype='object'),
#  Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#         'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#         'New_Price', 'Company', 'P_Company', 'P_Year', 'P_Engine', 'P_Power'],
#        dtype='object'))

# %%
data.to_csv('Processed.csv')

# %%
np.log(data.Seats).hist()

# %%
data.Seats.value_counts()
# Out:
# 5.0     5014
# 7.0      674
# 8.0      134
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# Name: Seats, dtype: int64

# %%
#bins = list(np.arange(-100, 800, 10))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data[(data['Seats']==10.0)]['Price'])
x = np.array(data[(data['Seats']==10.0)]['Price'])
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 4.279999999999999 3.65

# %%
data.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price', 'Company', 'Log_Price', 'P_Company', 'P_Location',
#        'P_Year', 'P_Engine', 'P_Power'],
#       dtype='object')

# %%
bins = list(np.arange(0, 250000, 10000))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(data['Kilometers_Driven'])
x = np.array(data['Kilometers_Driven'])
print(x.mean(), median)
result = plt.hist(x, bins, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 58659.30923694779 53000.0

# %%
bins = list(np.arange(5, 20, 0.5))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(np.log(data['Kilometers_Driven']))
x = np.array(np.log(data['Kilometers_Driven']))
print(x.mean(), median)
result = plt.hist(x, bins, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 10.756744299842605 10.87804719253426

# %%
data = data[~(data.Mileage.isnull())]
#test = test[~(test.Mileage.isnull())]

# %%
test[(test.Mileage.isnull())].shape
# Out:
# (0, 17)

# %%
data.shape, test.shape
# Out:
# ((5974, 20), (1234, 17))

# %%
def p5(item):
    """Function to extract first part of Mileage description and typecast to float"""
    s = str(item).split()
    num = s[0]
    return float(num)

def p6(item):
    s = str(item).split()
    m = s[1]
    return m

data['P_Mileage']=data['Mileage'].apply(p5)
data['P_Mileage_M']=data['Mileage'].apply(p6)

test['P_Mileage']=test['Mileage'].apply(p5)
test['P_Mileage_M']=test['Mileage'].apply(p6)

# %%
data.P_Mileage_M.value_counts()
# Out:
# kmpl     5908
# km/kg      66
# Name: P_Mileage_M, dtype: int64

# %%
data[data['P_Mileage_M']=='kmpl']['Fuel_Type'].value_counts()
# Out:
# Diesel    3195
# Petrol    2713
# Name: Fuel_Type, dtype: int64

# %%
data[data['P_Mileage_M']=='kmpl']['Price'].median()
# Out:
# 5.7

# %%
data[data['P_Mileage_M']=='km/kg']['Price'].median()
# Out:
# 3.15

# %%
data.Fuel_Type.value_counts()
# Out:
# Diesel    3195
# Petrol    2713
# CNG         56
# LPG         10
# Name: Fuel_Type, dtype: int64

# %%
data.P_Mileage.hist()

# %%
data[data.P_Mileage==0].shape
# Out:
# (56, 22)

# %%
#bins = list(np.arange(5, 20, 0.5))
plt.figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')
np.random.seed(6789)
median = np.median(np.log(data[data['P_Mileage']==13.50]['Price']))
x = np.array(np.log(data[data['P_Mileage']==13.50]['Price']))
print(x.mean(), median)
result = plt.hist(x, color='c', edgecolor='k', alpha=0.65)
plt.axvline(x.mean(), color='k', linestyle='dashed', linewidth=5)
plt.axvline(median, color='r', linestyle='dashed', linewidth=5)
# Out:
# 1.963913413780217 2.0307815363488606

# %%
data.P_Mileage.value_counts()
# Out:
# 18.90    172
# 17.00    171
# 18.60    119
# 20.36     88
# 21.10     87
# 17.80     85
# 16.00     76
# 20.00     71
# 12.80     70
# 15.10     69
# 18.00     69
# 18.50     67
# 13.00     66
# 22.70     66
# 16.80     59
# 12.99     58
# 16.47     58
# 0.00      56
# 23.10     52
# 25.80     51
# 22.32     50
# 22.90     47
# 19.70     47
# 17.50     46
# 24.30     43
# 13.50     42
# 15.00     41
# 24.00     41
# 21.40     41
# 11.50     41
#         ...
# 15.85      1
# 11.56      1
# 21.20      1
# 11.78      1
# 12.37      1
# 17.16      1
# 12.85      1
# 26.80      1
# 20.62      1
# 13.44      1
# 25.50      1
# 7.81       1
# 17.06      1
# 17.84      1
# 25.01      1
# 8.30       1
# 19.44      1
# 11.07      1
# 8.45       1
# 17.24      1
# 18.86      1
# 27.28      1
# 21.72      1
# 22.80      1
# 9.70       1
# 13.29      1
# 12.97      1
# 23.01      1
# 15.11      1
# 14.45      1
# Name: P_Mileage, Length: 430, dtype: int64

# %%
data.to_csv('Processed.csv')

# %%
data = pd.read_csv('Processed.csv')

# %%
test.to_csv('Processed_Test.csv')

# %%
test = pd.read_csv('Processed_Test.csv')

# %%
test.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                   0
# Seats                   0
# New_Price            1052
# Company                 0
# P_Company               0
# P_Year                  0
# P_Engine                0
# P_Power                 0
# P_Mileage               0
# P_Mileage_M             0
# dtype: int64

# %%
data.New_Price.value_counts()
# Out:
# 4.78 Lakh     6
# 63.71 Lakh    6
# 95.13 Lakh    6
# 11.26 Lakh    5
# 47.87 Lakh    5
# 4.98 Lakh     5
# 11.67 Lakh    5
# 44.28 Lakh    5
# 10.32 Lakh    4
# 6.62 Lakh     4
# 33.36 Lakh    4
# 8.1 Lakh      4
# 5.04 Lakh     4
# 28.05 Lakh    4
# 15.86 Lakh    4
# 20.74 Lakh    4
# 11.27 Lakh    4
# 48.18 Lakh    4
# 15.05 Lakh    4
# 11.15 Lakh    4
# 7.88 Lakh     4
# 19.18 Lakh    4
# 11.75 Lakh    4
# 7.63 Lakh     4
# 12.56 Lakh    4
# 8.71 Lakh     3
# 10.83 Lakh    3
# 8.68 Lakh     3
# 15.29 Lakh    3
# 6.54 Lakh     3
#              ..
# 17.7 Lakh     1
# 18.45 Lakh    1
# 12.27 Lakh    1
# 11.01 Lakh    1
# 19.91 Lakh    1
# 95.04 Lakh    1
# 15.17 Lakh    1
# 50.4 Lakh     1
# 53.72 Lakh    1
# 11.69 Lakh    1
# 16.6 Lakh     1
# 16.67 Lakh    1
# 12.47 Lakh    1
# 11.29 Lakh    1
# 7.52 Lakh     1
# 9.72 Lakh     1
# 7.67 Lakh     1
# 23.68 Lakh    1
# 8.95 Lakh     1
# 8.03 Lakh     1
# 7 Lakh        1
# 25.4 Lakh     1
# 7.14 Lakh     1
# 24.26 Lakh    1
# ...

# %%
data[(~(data['New_Price'].isnull()))&(data['Company']=='Honda')].loc[:,['New_Price','Price','Year','Company','Engine','Mileage', 'Power']]
# Out:
#        New_Price  Price  Year Company   Engine    Mileage      Power
# 2      8.61 Lakh   4.50  2011   Honda  1199 CC  18.2 kmpl   88.7 bhp
# 28    10.57 Lakh   9.90  2018   Honda  1199 CC  17.5 kmpl   88.7 bhp
# 208    8.54 Lakh   3.25  2013   Honda  1498 CC  27.4 kmpl   98.6 bhp
# 234   11.74 Lakh   3.87  2011   Honda  1497 CC  17.4 kmpl  117.3 bhp
# 290    8.85 Lakh   4.85  2015   Honda  1199 CC  18.2 kmpl   88.7 bhp
# 300   16.67 Lakh  12.69  2017   Honda  1497 CC  18.0 kmpl  117.3 bhp
# 311    6.62 Lakh   3.13  2012   Honda  1198 CC  18.5 kmpl   86.8 bhp
# 377   14.65 Lakh   9.48  2017   Honda  1497 CC  16.0 kmpl  117.3 bhp
# 411   12.51 Lakh   8.50  2017   Honda  1497 CC  15.4 kmpl  117.3 bhp
# 633   15.45 Lakh  10.79  2017   Honda  1498 CC  21.9 kmpl   98.6 bhp
# 654   15.02 Lakh   9.25  2017   Honda  1497 CC  16.0 kmpl  117.3 bhp
# 729   11.85 Lakh   5.70  2014   Honda  1497 CC  17.4 kmpl  117.3 bhp
# 745   16.04 Lakh  10.65  2015   Honda  1497 CC  18.0 kmpl  117.3 bhp
# ...

# %%
data.shape
# Out:
# (5974, 23)

# %%
data=pd.read_csv('Processed.csv')
test=pd.read_csv('Processed_Test.csv')

# %%
data.shape, test.shape
# Out:
# ((5974, 23), (1234, 20))

# %%
check = data[~data['New_Price'].isnull()]

# %%
check.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Location', 'Year', 'Kilometers_Driven',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power',
#        'Seats', 'New_Price', 'Price', 'Company', 'Log_Price', 'P_Company',
#        'P_Location', 'P_Year', 'P_Engine', 'P_Power', 'P_Mileage',
#        'P_Mileage_M'],
#       dtype='object')

# %%
check.shape
# Out:
# (823, 23)

# %%
check.reset_index(drop=True, inplace=True)

# %%
check['Now']=2019.5
# Out:
# C:\Users\Public\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def conv(item):
    string = item.split()
    print(string[1])
    if string[1]=='Cr':
        return float(string[0])*100
    else:
        return float(string[0])

check['P_New_Price']=check['New_Price'].apply(conv)
# Out:
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Cr
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Cr
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Cr
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# Lakh
# ...

# %%
check.P_New_Price.value_counts()
# Out:
# 4.78     6
# 95.13    6
# 63.71    6
# 47.87    5
# 11.67    5
# 11.26    5
# 4.98     5
# 44.28    5
# 11.27    4
# 7.63     4
# 15.86    4
# 19.18    4
# 7.88     4
# 5.04     4
# 48.18    4
# 12.56    4
# 10.32    4
# 8.10     4
# 11.15    4
# 15.05    4
# 6.62     4
# 28.05    4
# 20.74    4
# 33.36    4
# 11.75    4
# 7.36     3
# 4.09     3
# 5.61     3
# 26.95    3
# 12.68    3
#         ..
# 45.36    1
# 10.26    1
# 8.73     1
# 33.21    1
# 5.67     1
# 17.38    1
# 22.74    1
# 11.30    1
# 9.55     1
# 15.38    1
# 15.36    1
# 40.73    1
# 6.21     1
# 21.36    1
# 32.01    1
# 11.81    1
# 99.92    1
# 9.93     1
# 64.76    1
# 4.55     1
# 9.26     1
# 12.44    1
# 4.37     1
# 39.27    1
# 12.51    1
# 9.09     1
# 23.14    1
# 12.67    1
# 6.29     1
# 11.74    1
# Name: P_New_Price, Length: 540, dtype: int64

# %%
np.log(check.Kilometers_Driven).hist()

# %%
check['d_rate']=np.log(check['P_New_Price']-check['Price'])*np.log((check['Now']-check['Year'])*12)/(check['Kilometers_Driven'])
# Out:
# C:\Users\Public\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# C:\Users\Public\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
check.Company.value_counts()
# Out:
# Maruti           194
# Hyundai           96
# Toyota            82
# Honda             68
# BMW               57
# Tata              43
# Mercedes-Benz     42
# Volkswagen        42
# Renault           27
# Mahindra          25
# Ford              25
# Audi              24
# Skoda             19
# Mini              16
# Nissan            15
# Jeep              15
# Land              10
# Datsun             7
# Mitsubishi         6
# Jaguar             4
# Volvo              3
# Isuzu              1
# Porsche            1
# Fiat               1
# Name: Company, dtype: int64

# %%
grouped = check.loc[:,['P_New_Price','Price','Year','d_rate','Engine','Kilometers_Driven','Mileage','Name','Company']].sort_values(['d_rate']).groupby('Company')

# %%
print(grouped)

# %%
len(grouped)
# Out:
# 24

# %%
grouped1=check.sort_values(['P_New_Price']).groupby('Company')

# %%
data['G_New_Price']=0
list_data=[]
name_list=[]
combo_num=[]
for name, objects in grouped1:
    #print(name)
    name_list.append(name)
    total = objects['P_New_Price'].sum()
    length = len(objects)
    if length==0:
        objects['G_New_Price'] = 0
    else:
        objects['G_New_Price'] = total / length
    list_data.append(total/length)
    combo_num.append(objects['Company'].unique().tolist()[0])

data['G_New_Price']=data['Company'].map(dict(zip(combo_num,list_data)))
# Out:
# C:\Users\Public\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
test['G_New_Price']=test['Company'].map(dict(zip(combo_num,list_data)))

# %%
test.shape, data.shape
# Out:
# ((1234, 21), (5974, 24))

# %%
data.to_csv('Features.csv')
test.to_csv('Features_Test.csv')

# %%
grouped1=check.sort_values(['P_New_Price']).groupby('Name')
data['G_New_Price1']=0
list_data=[]
name_list=[]
combo_num=[]
for name, objects in grouped1:
    #print(name)
    name_list.append(name)
    total = objects['P_New_Price'].sum()
    length = len(objects)
    if length==0:
        objects['G_New_Price1'] = 0
    else:
        objects['G_New_Price1'] = total / length
    list_data.append(total/length)
    combo_num.append(objects['Name'].unique().tolist()[0])
'''    
list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 

print(len(d), data.shape)
    
#data['P_Company_Median'] = d
'''
data['G_New_Price1']=data['Name'].map(dict(zip(combo_num,list_data)))
# Out:
# C:\Users\Public\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test['G_New_Price1']=test['Name'].map(dict(zip(combo_num,list_data)))

# %%
test[test.G_New_Price.isnull()].shape

# %%
data.to_csv('Features.csv')
test.to_csv('Features_Test.csv')

# %%
data['G_New_Price']=np.where(data['Company']=='Chevrolet',9.5,data['G_New_Price'])

# %%
data[data.G_New_Price.isnull()]['Company'].value_counts()

# %%
data['G_New_Price']=np.where(data['Company']=='Bentley',136,data['G_New_Price'])

# %%
data['G_New_Price']=np.where(data['Company']=='Force',11.5,data['G_New_Price'])

# %%
data[data.G_New_Price.isnull()]['Company'].value_counts()

# %%
data['G_New_Price']=np.where(data['Company']=='ISUZU',24,data['G_New_Price'])

# %%
data['G_New_Price']=np.where(data['Company']=='Lamborghini',150,data['G_New_Price'])

# %%
data['G_New_Price']=np.where(data['Company']=='Ambassador',3,data['G_New_Price'])

# %%
data[data.G_New_Price.isnull()]['Company'].value_counts()

# %%
data['G_New_Price']=np.where(data['Company']=='Smart',9,data['G_New_Price'])

# %%
test[test.G_New_Price.isnull()]['Company'].value_counts()

# %%
test['G_New_Price']=np.where(test['Company']=='Chevrolet',9.5,test['G_New_Price'])
test['G_New_Price']=np.where(test['Company']=='Bentley',136,test['G_New_Price'])
test['G_New_Price']=np.where(test['Company']=='ISUZU',24,test['G_New_Price'])

# %%
data.to_csv('Features.csv')
test.to_csv('Features_Test.csv')

# %%
data.shape, test.shape

# %%
data.columns, test.columns

# %% [markdown]
# ### New Features

# %% [raw]
# Architecture:
#
# MAKE FIVE SECTIONS
# Take mean of target
# Take median of target
# Take mean/total of target
#
# Also, normalize the rest

# %%
c_grouped = data.groupby('P_Company')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import KFold
kf=KFold(n_splits=5)

# %%
c_grouped = data.groupby('P_Company')  # Data Grouped by company
list_data=[]
list_data2=[]

for key, item in c_grouped:
    print('in company')
    kf.get_n_splits(item)  # Get number of splits
    mini_list_data=[]
    mini_list_data2=[]
    for train_index, test_index in kf.split(item): # For each split (group), find group mean & median price
        item_train, item_test = item.iloc[train_index], item.iloc[test_index]
        item_test['P_Company_Mean']=item_train.Price.mean()
        item_test['P_Company_Median']=item_train.Price.median()
        mini_list_data.append(item_test['P_Company_Mean'])  # Within each split, compute mean for CV training set
        mini_list_data2.append(item_test['P_Company_Median'])
    list2=[]
    for df in mini_list_data:   # List which was storing the mean information
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)
    item['P_Company_Mean'] = g
    
    list2=[]
    for df in mini_list_data2:   # List which was storing the median information
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)
        
    item['P_Company_Median'] = g
    
    list_data.append(item['P_Company_Mean'])
    list_data2.append(item['P_Company_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    if(i==0):
        i = imp_avg
    if(i == -1):
        i = non_imp_avg
    d.append(i) 
data['P_Company_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 
data['P_Company_Median'] = d

# %%
grouped = test.groupby('P_Company')

list_data=[]
list_data2=[]

for key, item in grouped:
    print('in company')
    item['P_Company_Mean']=data[data['P_Company']==key]['Price'].mean()
    item['P_Company_Median']=data[data['P_Company']==key]['Price'].median()
    list_data.append(item['P_Company_Mean'])
    list_data2.append(item['P_Company_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 
print(len(d),test.shape)  
test['P_Company_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 

print(len(d),test.shape)
test['P_Company_Median'] = d

# %%
len(list_data), len(list_data2)

# %%
c_grouped = data.groupby('Location')
list_data=[]
list_data2=[]

for key, item in c_grouped:
    print('in location')
    kf.get_n_splits(item)
    mini_list_data=[]
    mini_list_data2=[]
    for train_index, test_index in kf.split(item):
        item_train, item_test = item.iloc[train_index], item.iloc[test_index]
        item_test['P_Location_Mean']=item_train.Price.mean()
        item_test['P_Location_Median']=item_train.Price.median()
        mini_list_data.append(item_test['P_Location_Mean'])
        mini_list_data2.append(item_test['P_Location_Median'])
    list2=[]
    for df in mini_list_data:
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)

    d = []
    for i in g:
        if(i==0):
            i = imp_avg
        if(i == -1):
            i = non_imp_avg
        d.append(i) 
        
    item['P_Location_Mean'] = d
    
    list2=[]
    for df in mini_list_data2:
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)

    d = []
    for i in g:
        if(i==0):
            i = imp_avg
        if(i == -1):
            i = non_imp_avg
        d.append(i) 
        
    item['P_Location_Median'] = d
    
    #print(len(d))
    #print(len(item))
    list_data.append(item['P_Location_Mean'])
    list_data2.append(item['P_Location_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    if(i==0):
        i = imp_avg
    if(i == -1):
        i = non_imp_avg
    d.append(i) 
data['P_Location_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    if(i==0):
        i = imp_avg
    if(i == -1):
        i = non_imp_avg
    d.append(i) 
data['P_Location_Median'] = d

# %%
grouped = test.groupby('Location')

list_data=[]
list_data2=[]

for key, item in grouped:
    print('in company')
    item['Location_Mean']=data[data['Location']==key]['Price'].mean()
    item['Location_Median']=data[data['Location']==key]['Price'].median()
    list_data.append(item['Location_Mean'])
    list_data2.append(item['Location_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 
print(len(d),test.shape)  
test['Location_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 

print(len(d),test.shape)
test['Location_Median'] = d

# %%
c_grouped = data.groupby('P_Year')
list_data=[]
list_data2=[]

for key, item in c_grouped:
    print('in year')
    kf.get_n_splits(item)
    mini_list_data=[]
    mini_list_data2=[]
    for train_index, test_index in kf.split(item):
        item_train, item_test = item.iloc[train_index], item.iloc[test_index]
        item_test['P_Year_Mean']=item_train.Price.mean()
        item_test['P_Year_Median']=item_train.Price.median()
        mini_list_data.append(item_test['P_Year_Mean'])
        mini_list_data2.append(item_test['P_Year_Median'])
    list2=[]
    for df in mini_list_data:
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)

    d = []
    for i in g:
        if(i==0):
            i = imp_avg
        if(i == -1):
            i = non_imp_avg
        d.append(i) 
        
    item['P_Year_Mean'] = d
    
    list2=[]
    for df in mini_list_data2:
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)

    d = []
    for i in g:
        if(i==0):
            i = imp_avg
        if(i == -1):
            i = non_imp_avg
        d.append(i) 
        
    item['P_Year_Median'] = d
    
    #print(len(d))
    #print(len(item))
    list_data.append(item['P_Year_Mean'])
    list_data2.append(item['P_Year_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    if(i==0):
        i = imp_avg
    if(i == -1):
        i = non_imp_avg
    d.append(i) 
data['P_Year_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    if(i==0):
        i = imp_avg
    if(i == -1):
        i = non_imp_avg
    d.append(i) 
data['P_Year_Median'] = d

# %%
grouped = test.groupby('P_Year')

list_data=[]
list_data2=[]

for key, item in grouped:
    print('in company')
    item['P_Year_Mean']=data[data['P_Year']==key]['Price'].mean()
    item['P_Year_Median']=data[data['P_Year']==key]['Price'].median()
    list_data.append(item['P_Year_Mean'])
    list_data2.append(item['P_Year_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 
print(len(d),test.shape)  
test['P_Year_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 

print(len(d),test.shape)
test['P_Year_Median'] = d

# %%
data.columns, test.columns

# %%
data.to_csv('Features.csv')
test.to_csv('Features_Test.csv')

# %%
data['Now']=2019.5
test['Now']=2019.5

# %%
# Kmpm is the average KM driven per month (Indicates the usage/wear&tear of the car)  
data['Kmpm']=data['Kilometers_Driven']/((data['Now']-data['Year'])*12)
test['Kmpm']=test['Kilometers_Driven']/((test['Now']-test['Year'])*12)

# %%
data.columns, test.columns

# %%
data.to_csv('Features.csv')
test.to_csv('Features_test.csv')

# %%
data.shape, test.shape

# %%
data.Transmission.value_counts()

# %%
c_grouped = data.groupby('Transmission')
list_data=[]
list_data2=[]

for key, item in c_grouped:
    print('in trans')
    kf.get_n_splits(item)
    mini_list_data=[]
    mini_list_data2=[]
    for train_index, test_index in kf.split(item):
        item_train, item_test = item.iloc[train_index], item.iloc[test_index]
        item_test['P_Transmission_Mean']=item_train.Price.mean()
        item_test['P_Transmission_Median']=item_train.Price.median()
        mini_list_data.append(item_test['P_Transmission_Mean'])
        mini_list_data2.append(item_test['P_Transmission_Median'])
    list2=[]
    for df in mini_list_data:
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)

    d = []
    for i in g:
        if(i==0):
            i = imp_avg
        if(i == -1):
            i = non_imp_avg
        d.append(i) 
        
    item['P_Transmission_Mean'] = d
    
    list2=[]
    for df in mini_list_data2:
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)

    d = []
    for i in g:
        if(i==0):
            i = imp_avg
        if(i == -1):
            i = non_imp_avg
        d.append(i) 
        
    item['P_Transmission_Median'] = d
    
    #print(len(d))
    #print(len(item))
    list_data.append(item['P_Transmission_Mean'])
    list_data2.append(item['P_Transmission_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    if(i==0):
        i = imp_avg
    if(i == -1):
        i = non_imp_avg
    d.append(i) 
data['P_Transmission_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    if(i==0):
        i = imp_avg
    if(i == -1):
        i = non_imp_avg
    d.append(i) 
data['P_Transmission_Median'] = d

# %%
grouped = test.groupby('Transmission')

list_data=[]
list_data2=[]

for key, item in grouped:
    print('in company')
    item['P_Transmission_Mean']=data[data['Transmission']==key]['Price'].mean()
    item['P_Transmission_Median']=data[data['Transmission']==key]['Price'].median()
    list_data.append(item['P_Transmission_Mean'])
    list_data2.append(item['P_Transmission_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 
print(len(d),test.shape)  
test['P_Transmission_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 

print(len(d),test.shape)
test['P_Transmission_Median'] = d

# %%
c_grouped = data.groupby('Fuel_Type')
list_data=[]
list_data2=[]

for key, item in c_grouped:
    print('in trans')
    kf.get_n_splits(item)
    mini_list_data=[]
    mini_list_data2=[]
    for train_index, test_index in kf.split(item):
        item_train, item_test = item.iloc[train_index], item.iloc[test_index]
        item_test['P_Fuel_Mean']=item_train.Price.mean()
        item_test['P_Fuel_Median']=item_train.Price.median()
        mini_list_data.append(item_test['P_Fuel_Mean'])
        mini_list_data2.append(item_test['P_Fuel_Median'])
    list2=[]
    for df in mini_list_data:
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)

    d = []
    for i in g:
        if(i==0):
            i = imp_avg
        if(i == -1):
            i = non_imp_avg
        d.append(i) 
        
    item['P_Fuel_Mean'] = d
    
    list2=[]
    for df in mini_list_data2:
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)

    d = []
    for i in g:
        if(i==0):
            i = imp_avg
        if(i == -1):
            i = non_imp_avg
        d.append(i) 
        
    item['P_Fuel_Median'] = d
    
    #print(len(d))
    #print(len(item))
    list_data.append(item['P_Fuel_Mean'])
    list_data2.append(item['P_Fuel_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    if(i==0):
        i = imp_avg
    if(i == -1):
        i = non_imp_avg
    d.append(i) 
data['P_Fuel_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    if(i==0):
        i = imp_avg
    if(i == -1):
        i = non_imp_avg
    d.append(i) 
data['P_Fuel_Median'] = d

# %%
grouped = test.groupby('Fuel_Type')

list_data=[]
list_data2=[]

for key, item in grouped:
    print('in company')
    item['P_Fuel_Mean']=data[data['Fuel_Type']==key]['Price'].mean()
    item['P_Fuel_Median']=data[data['Fuel_Type']==key]['Price'].median()
    list_data.append(item['P_Fuel_Mean'])
    list_data2.append(item['P_Fuel_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 
print(len(d),test.shape)  
test['P_Fuel_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 

print(len(d),test.shape)
test['P_Fuel_Median'] = d

# %%
c_grouped = data.groupby('Owner_Type')
list_data=[]
list_data2=[]

for key, item in c_grouped:
    print('in trans')
    kf.get_n_splits(item)
    mini_list_data=[]
    mini_list_data2=[]
    for train_index, test_index in kf.split(item):
        item_train, item_test = item.iloc[train_index], item.iloc[test_index]
        item_test['P_Owner_Mean']=item_train.Price.mean()
        item_test['P_Owner_Median']=item_train.Price.median()
        mini_list_data.append(item_test['P_Owner_Mean'])
        mini_list_data2.append(item_test['P_Owner_Median'])
    list2=[]
    for df in mini_list_data:
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)

    d = []
    for i in g:
        if(i==0):
            i = imp_avg
        if(i == -1):
            i = non_imp_avg
        d.append(i) 
        
    item['P_Owner_Mean'] = d
    
    list2=[]
    for df in mini_list_data2:
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)

    d = []
    for i in g:
        if(i==0):
            i = imp_avg
        if(i == -1):
            i = non_imp_avg
        d.append(i) 
        
    item['P_Owner_Median'] = d
    
    #print(len(d))
    #print(len(item))
    list_data.append(item['P_Owner_Mean'])
    list_data2.append(item['P_Owner_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    if(i==0):
        i = imp_avg
    if(i == -1):
        i = non_imp_avg
    d.append(i) 
data['P_Owner_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    if(i==0):
        i = imp_avg
    if(i == -1):
        i = non_imp_avg
    d.append(i) 
data['P_Owner_Median'] = d

# %%
grouped = test.groupby('Owner_Type')

list_data=[]
list_data2=[]

for key, item in grouped:
    print('in company')
    item['P_Owner_Mean']=data[data['Owner_Type']==key]['Price'].mean()
    item['P_Owner_Median']=data[data['Owner_Type']==key]['Price'].median()
    list_data.append(item['P_Owner_Mean'])
    list_data2.append(item['P_Owner_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 
print(len(d),test.shape)  
test['P_Owner_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 

print(len(d),test.shape)
test['P_Owner_Median'] = d

# %%
test.P_Transmission_Mean.value_counts()

# %%
test.Transmission.value_counts()

# %%
len(item)

# %%
data.Seats.value_counts()

# %%
c_grouped = data.groupby('Seats')
list_data=[]
list_data2=[]

kf=KFold(n_splits=3)

for key, item in c_grouped:
    print('in trans')
    print(len(item))
    kf.get_n_splits(item)
    mini_list_data=[]
    mini_list_data2=[]
    for train_index, test_index in kf.split(item):
        item_train, item_test = item.iloc[train_index], item.iloc[test_index]
        item_test['P_Seats_Mean']=item_train.Price.mean()
        item_test['P_Seats_Median']=item_train.Price.median()
        mini_list_data.append(item_test['P_Seats_Mean'])
        mini_list_data2.append(item_test['P_Seats_Median'])
    list2=[]
    for df in mini_list_data:
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)

    d = []
    for i in g:
        if(i==0):
            i = imp_avg
        if(i == -1):
            i = non_imp_avg
        d.append(i) 
        
    item['P_Seats_Mean'] = d
    
    list2=[]
    for df in mini_list_data2:
        list2.append(df.values)

    g = []
    for i in list2:
        for k in i:
            g.append(k)

    d = []
    for i in g:
        if(i==0):
            i = imp_avg
        if(i == -1):
            i = non_imp_avg
        d.append(i) 
        
    item['P_Seats_Median'] = d
    
    #print(len(d))
    #print(len(item))
    list_data.append(item['P_Seats_Mean'])
    list_data2.append(item['P_Seats_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    if(i==0):
        i = imp_avg
    if(i == -1):
        i = non_imp_avg
    d.append(i) 
data['P_Seats_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    if(i==0):
        i = imp_avg
    if(i == -1):
        i = non_imp_avg
    d.append(i) 
data['P_Seats_Median'] = d

# %%
grouped = test.groupby('Seats')

list_data=[]
list_data2=[]

for key, item in grouped:
    print('in company')
    item['P_Seats_Mean']=data[data['Seats']==key]['Price'].mean()
    item['P_Seats_Median']=data[data['Seats']==key]['Price'].median()
    list_data.append(item['P_Seats_Mean'])
    list_data2.append(item['P_Seats_Median'])

list1=[]
for df in list_data:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 
print(len(d),test.shape)  
test['P_Seats_Mean'] = d

list1=[]
for df in list_data2:
    list1.append(df.values)

g = []
for i in list1:
    for k in i:
        g.append(k)

d = []
for i in g:
    d.append(i) 

print(len(d),test.shape)
test['P_Seats_Median'] = d

# %%
data.to_csv('Features.csv')
test.to_csv('Features_test.csv')

# %%
data.describe()

# %%
data.columns, test.columns, data.shape, test.shape

# %%
test.rename(columns={'Location_Mean':'P_Location_Mean','Location_Median':'P_Location_Median'}, inplace=True)

# %%
test.to_csv('Features_test.csv')

# %%
np.log(data.P2_Engine).hist()

# %%
(data.P2_Engine).hist()

# %%
data.P3_Power.hist()

# %%
check = np.where(data.P3_Power==0, 0.001, data.P3_Power)

# %%
np.log(pd.Series(check)).hist()

# %%
data.columns.tolist()

# %%
import pandas as pd
import numpy as np
data=pd.read_csv('Features.csv')
test=pd.read_csv('Features_test.csv')

# %%
'''
data['P3_Engine']=np.log(data['P2_Engine'])
test['P3_Engine']=np.log(test['P2_Engine'])

data['P4_Power']=np.log(data['P3_Power'])
test['P4_Power']=np.log(test['P3_Power'])
'''

# %%
cols = ['P2_Engine', 'P3_Power', 'P_Mileage', 'Kilometers_Driven', 'G_New_Price', 'G_New_Price1', 'P_Company_Mean',
       'P_Company_Median', 'P_Year_Mean', 'P_Year_Median', 'P_Location_Mean', 'P_Location_Median','Kmpm', 'P_Transmission_Mean', 'P_Transmission_Median','P_Owner_Mean','P_Owner_Median','P_Fuel_Mean','P_Fuel_Median','P_Seats_Median','P_Seats_Mean']

data_p = data.loc[:,cols]

# %%
for col in cols:
    print(data[data[col]==0].shape, col, test[test[col]==0].shape)

# %%
for col in cols:
    data[col]=np.log(data[col])
    
for col in cols:
    test[col]=np.log(test[col])

# %%
data.to_csv('Normalized_Features.csv')
test.to_csv('Normalized_Features_Test.csv')

# %%
from sklearn import preprocessing
x = pd.DataFrame(data_p) #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
data_p= x_scaled

# %%
data_p.shape

# %%
data_p=pd.DataFrame(data_p, columns=cols)

# %%
data_p.Kilometers_Driven.hist()

# %%
data_p.columns

# %%
data.P_Fuel_Median.value_counts()

# %%
for col in data_p.columns:
    data[col]=data_p[col]

# %%
test_p = test.loc[:,cols]

# %%
x = pd.DataFrame(test_p) #returns a numpy array
x_scaled = min_max_scaler.transform(x)
test_p= x_scaled

# %%
test_p=pd.DataFrame(test_p,columns=cols)

# %%
for col in test_p.columns:
    test[col]=test_p[col]

# %%
data.to_csv('Normalized_Features.csv')
test.to_csv('Normalized_Features_Test.csv')

# %%
test.shape

# %%
data.isnull().sum()

# %%
test.isnull().sum()

# %%
data[data['Kmpm'].isnull()]
